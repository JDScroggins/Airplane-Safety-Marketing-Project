# %%
import pandas as pd

# %%
auto_df = pd.read_csv("FileName.txt", delimiter="\t", index_col=0)

# %%
auto_df.head()
# Out:
#             1994  1995  1996  1997  1998  1999  2000  2001  2002  2003  ...  \
# State                                                                   ...
# Alabama     1083  1114  1146  1192  1071  1138   996   991  1038  1004  ...
# Alaska        85    87    81    77    70    79   106    89    89    98  ...
# Arizona      904  1035   994   951   980  1024  1036  1051  1132  1118  ...
# Arkansas     609   631   615   660   625   604   652   611   640   640  ...
# California  4232  4192  3989  3688  3494  3559  3753  3956  4088  4224  ...
#
#             2007   2008   2009   2010   2011   2012   2013   2014   \
# State
# Alabama      1.81   1.63   1.38   1.34   1.38   1.33   1.31   1.25
# Alaska       1.59   1.27   1.30   1.17   1.57   1.23   1.05   1.50
# Arizona      1.70   1.52   1.31   1.27   1.39   1.37   1.40   1.23
# Arkansas     1.96   1.81   1.80   1.70   1.67   1.67   1.49   1.38
# California   1.22   1.05   0.95   0.84   0.88   0.91   0.94   0.93
#
# ...

# %%
col_list = auto_df.columns
col_list
# Out:
# Index(['1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', 'Difference, 1994 -- 2014', '1994 ', '1995 ',
#        '1996 ', '1997 ', '1998 ', '1999 ', '2000 ', '2001 ', '2002 ', '2003 ',
#        '2004 ', '2005 ', '2006 ', '2007 ', '2008 ', '2009 ', '2010 ', '2011 ',
#        '2012 ', '2013 ', '2014 ', 'Difference, 1994 -- 2014 ', 'Unnamed: 45'],
#       dtype='object')

# %%
col_list = [ '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', 'Difference, 1994 -- 2014', '1994b ',
       '1995b ', '1996b ', '1997b ', '1998b ', '1999b ', '2000b ', '2001b ', '2002b ',
       '2003b ', '2004b ', '2005b ', '2006b ', '2007b ', '2008b ', '2009b ', '2010b ',
       '2011b ', '2012b ', '2013b ', '2014b ', 'Difference, 1994 -- 2014 ',
       'Unnamed: 45']

# %%
auto_df.columns = [ '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', 'Difference, 1994 -- 2014', '1994b ',
       '1995b ', '1996b ', '1997b ', '1998b ', '1999b ', '2000b ', '2001b ', '2002b ',
       '2003b ', '2004b ', '2005b ', '2006b ', '2007b ', '2008b ', '2009b ', '2010b ',
       '2011b ', '2012b ', '2013b ', '2014b ', 'Difference, 1994 -- 2014 ',
       'Unnamed: 45']

# %%
auto_df['total_00_14'] = auto_df['2000'] + auto_df['2001'] + auto_df['2002'] + auto_df['2003'] + auto_df['2004']+ auto_df['2005']+ auto_df['2006']+auto_df['2007']+ auto_df['2008']+ auto_df['2009']+ auto_df['2010']+auto_df['2011']+ auto_df['2012']+ auto_df['2013']+ auto_df['2014']

# %%
auto_df.to_excel("Autocrash.xlsx",
             sheet_name='crash')

# %%
plane = pd.read_excel('Accidents and fatalities per year.xlsx', sheet_name='Accidents and fatalities per ye', skiprows=1)

# %%
plane.head()
# Out:
#    Year  Accidents   Fatalities  Unnamed: 3  Accidents .1  Fatalities.1  \
# 0  1946          73         842         NaN            73           842
# 1  1947          82        1083         NaN            84          1093
# 2  1948          99        1303         NaN           100          1328
# 3  1949          81        1109         NaN            84          1155
# 4  1950          71        1124         NaN            71          1124
#
#    Unnamed: 6  Accidents .2  Fatalities.2  Unnamed: 9  ...  Unnamed: 12  \
# 0         NaN            54           779         NaN  ...          NaN
# 1         NaN            53           994         NaN  ...          NaN
# 2         NaN            63          1172         NaN  ...          NaN
# 3         NaN            61          1076         NaN  ...          NaN
# 4         NaN            46          1036         NaN  ...          NaN
#
#    World air traffic (departures)  1 accident \nper x flights  \
# ...

# %%
plane = plane.dropna(axis=1)

# %%
plane
# Out:
#      Year  Accidents   Fatalities  Accidents .1  Fatalities.1  Accidents .2  \
# 0    1946          73         842            73           842            54
# 1    1947          82        1083            84          1093            53
# 2    1948          99        1303           100          1328            63
# 3    1949          81        1109            84          1155            61
# 4    1950          71        1124            71          1124            46
# ..    ...         ...         ...           ...           ...           ...
# 71   2017          14          59            14            59             5
# 72   2018          18         561            19           562            11
# 73   2019          23         287            23           287            14
# 74   2020           8         136            10           318             4
# 75  TOTAL        3881       80039          4054         86961          2388
#
#     Fatalities.2  Accidents .3  Fatalities.3
# ...

# %%
plane.to_excel("planecrash.xlsx",
             sheet_name='crash')

# %%
crash2 = pd.read_excel("CrashReport (1).xls.xlsx", skiprows=6)
crash2 = crash2.rename(columns = {'Unnamed: 0': 'Year'})
crash2 = crash2.dropna()

# %%
crash2 = crash2.drop(index=11)

# %%
crash2['Year'] = crash2['Year'].astype(str).astype(int)

# %%
crash2
# Out:
#     Year  January  February   March   April     May    June    July  August  \
# 1   2005   2817.0    2618.0  2885.0  3239.0  3318.0  3381.0  3761.0  3501.0
# 2   2006   2931.0    2695.0  3042.0  3138.0  3345.0  3383.0  3527.0  3474.0
# 3   2007   2732.0    2618.0  3092.0  3041.0  3312.0  3281.0  3460.0  3325.0
# 4   2008   2575.0    2586.0  2549.0  2722.0  2887.0  3029.0  3018.0  3224.0
# 5   2009   2377.0    2167.0  2349.0  2592.0  2780.0  2750.0  2787.0  2865.0
# 6   2010   2101.0    1830.0  2213.0  2552.0  2704.0  2569.0  2852.0  2825.0
# 7   2011   2088.0    1880.0  2220.0  2338.0  2578.0  2624.0  2910.0  2749.0
# 8   2012   2283.0    2127.0  2487.0  2434.0  2672.0  2789.0  2833.0  2844.0
# 9   2013   2230.0    1952.0  2356.0  2300.0  2532.0  2692.0  2660.0  2899.0
# 10  2014   2168.0    1893.0  2245.0  2308.0  2596.0  2583.0  2696.0  2800.0
#
#     September  October  November  December    Total
# 1      3424.0   3631.0    3436.0    3241.0  39252.0
# ...

# %%
crash2.to_excel("Autocrash2.xlsx",
             sheet_name='Acrash')

# %%
gas = pd.read_excel('PET_PRI_GND_DCUS_NUS_M.xls', skiprows=2, sheet_name = "Data 1")

# %%
gas['day'] = gas['Date'].dt.day
gas['month'] = gas['Date'].dt.month
gas['year'] = gas['Date'].dt.year

# %%
gas
# Out:
#           Date  \
# 0   1990-08-15
# 1   1990-09-15
# 2   1990-10-15
# 3   1990-11-15
# 4   1990-12-15
# ..         ...
# 365 2021-01-15
# 366 2021-02-15
# 367 2021-03-15
# 368 2021-04-15
# 369 2021-05-15
#
#      U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 365                                              2.420
# 366                                              2.587
# 367                                              2.898
# 368                                              2.948
# 369                                              3.076
#
# ...

# %%
gas.to_excel("gas.xlsx",
             sheet_name='gas')

# %%
flight_cost = pd.read_csv('Airfares_20210617164529.csv', skiprows=1)
flight_cost = flight_cost.dropna()

# %%
flight_cost.head()
# Out:
#    Year  Quarter  U.S. Average (Current $)  \
# 0  1995      1.0                    296.90
# 1  1995      2.0                    296.80
# 2  1995      3.0                    287.51
# 3  1995      4.0                    287.78
# 4  1996      1.0                    283.97
#
#    U.S. Average (Inflation-Adjusted $)  US Domestic Average (Current $)  \
# 0                               512.38                           296.90
# 1                               507.73                           296.80
# 2                               489.70                           287.51
# 3                               487.80                           287.78
# 4                               477.00                           283.97
#
#    US Domestic Average (Inflation-Adjusted $)
# 0                                      512.38
# 1                                      507.73
# 2                                      489.70
# 3                                      487.80
# ...

# %%
flight_cost.to_excel("flight.xlsx",
             sheet_name='cost')

# %%
revenue = pd.read_excel('Passenger Revenue -- Total System Operations.xls', skiprows=3)
revenue = revenue.drop(index = [0,9,25,27])
revenue = revenue.drop(columns = ['Unnamed: 1'])
revenue = revenue.set_index('Unnamed: 0').transpose()
revenue
# Out:
# Unnamed: 0     American  Continental       Delta  Northwest       United  \
# 1995        13325.90800     4354.185  11385.9030   7761.950  13027.39800
# 1996        13631.84400     4885.152  11980.5140   8598.293  14246.99200
# 1997        14283.83100     5685.845  12772.8790   8721.942  15068.62100
# 1998        14688.24400     6388.217  13179.0370   7512.895  15201.58100
# 1999        14455.55400     6974.511  13203.0190   8587.190  15440.96300
# 2000        16370.89500     8062.050  14138.0170   9523.308  16602.87200
# 2001        14083.50900     7156.341  11875.6740   8218.602  13465.98900
# 2002        14418.27000     6584.694  10734.1890   7753.333  11518.66600
# 2003        14235.51200     6556.093  10272.0120   7616.695  10618.79700
# 2004        14983.27100     7129.402  10822.7160   8431.825  11953.66800
# 2005        16571.82500     7942.918  11346.2540   8837.980  12460.23200
# 2006        17843.28300     9302.644  11660.4120   9051.059  13889.78400
# ...

# %%
revenue.to_excel("revenue.xlsx",
             sheet_name='revenue')

# %%
stats = pd.read_excel('table_02_14_111720.xlsx', header=1)
stats = stats.dropna()
stats
# Out:
#                         Unnamed: 0    1960d    1965d         1970d  \
# 0                 Total fatalities      787     1029   1310.000000
# 1  Total seriously injured persons        U        U    715.000000
# 2               Total accidentsa,b     4793     5196   4712.000000
# 3        Total accidentsa,b, fatal      429      538    641.000000
# 4         Flight hours (thousands)    13121    16733  26030.000000
# 6                       Fatalities  5.99802  6.14952      5.032655
# 7       Seriously injured persons         U        U      2.746831
# 8               Total accidentsa,b  36.5292  31.0524     18.102190
# 9        Total accidents, fatala,b  3.26957   3.2152      2.462543
#
#            1975          1980          1985          1990          1991  \
# 0   1252.000000   1239.000000    956.000000    770.000000    800.000000
# 1    769.000000    681.000000    501.000000    409.000000    431.000000
# 2   3995.000000   3590.000000   2739.000000   2242.000000   2197.000000
# ...

# %%
stats.to_excel("stats.xlsx",
             sheet_name='stats')
